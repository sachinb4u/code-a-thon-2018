# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
sample_df = pd.read_excel('SystemLogsDataset-temp.xlsx')
sample_df.head()
# Out:
#    AvgBackgroundQ  AvgWorkflowQ  AvgThreadPoolSize  NodeId  IsProductReleased  \
# 0             164            18                 10      76                  1
# 1             231             5                 13      65                  1
# 2             159            41                 11      66                  0
# 3             323            31                 13      61                  1
# 4             289            13                 10      76                  1
#
#    UiNodeThreadsCount  CatalogSearchTime  NetworkConnectivitySNV-US1  \
# 0                   1                  9                           1
# 1                 567                  5                           1
# 2                 322                 14                           1
# 3                 318                 16                           1
# 4                -156                 36                           1
#
#    LogSizeVolumePercent           Label                Date CloudHealthIndex
# 0                 0.232    NetworkIssue 2017-01-01 00:00:00             FAIR
# 1                 0.326    NetworkIssue 2017-01-01 00:30:00         CRITICAL
# 2                 0.890      OrderIssue 2017-01-01 01:00:00             GOOD
# 3                 0.353    InvoiceIssue 2017-01-01 01:30:00         CRITICAL
# 4                 0.748  WorkspaceIssue 2017-01-01 02:00:00         CRITICAL

# %% [markdown]
# ### Pipeline and Estimator

# %%
from sklearn.base import BaseEstimator, TransformerMixin

incidentTypes = ['NoIssue', 'DBConnectionIssue', 'InvoiceIssue', 'OrderIssue', 'CommunityIssue',
                 'WorkspaceIssue' , 'NetworkIssue', 'CommunityHealthIssue' ]

incidentTypesDict = {'NoIssue' : 0, 'DBConnectionIssue' :1, 'InvoiceIssue' :2, 'OrderIssue' :3, 'CommunityIssue' :4,
                 'WorkspaceIssue' :5 , 'NetworkIssue' :6, 'CommunityHealthIssue':7 }

cloudHealthValues = ['FAIR', 'GOOD', 'CRITICAL']

class Preprocessor(BaseEstimator, TransformerMixin):
    """Custom Preprocessing Estimator for the custom case
    
    """
    
    def __init___(self):
        pass
    
    def transform(self, df):
        
        pred_vars = ['AvgBackgroundQ', 'AvgThreadPoolSize', 'AvgWorkflowQ',
       'CatalogSearchTime', 'CloudHealthIndex', 'Date', 'IsProductReleased',
        'LogSizeVolumePercent', 'NetworkConnectivitySNV-US1', 'UiNodeThreadsCount']
        
        df = df[pred_vars]
        
        # Make all negative values to NaN so that it can be replaced with single value
        df['AvgBackgroundQ'][df['AvgBackgroundQ'] < 1] = np.NAN
        df['AvgThreadPoolSize'][df['AvgThreadPoolSize'] < 1] = np.NAN
        df['AvgWorkflowQ'][df['AvgWorkflowQ'] < 1] = np.NAN
        df['CatalogSearchTime'][df['CatalogSearchTime'] < 1] = np.NAN
        df['UiNodeThreadsCount'][df['UiNodeThreadsCount'] < 1] = np.NAN
        
        df = df.fillna(-999)
        
        df1 = df.apply(lambda rec : pd.Series({'Day' : rec['Date'].day, 
                      'Month' : rec['Date'].month, 
                      'Year' :  rec['Date'].year,
                      'Hour' : rec['Date'].hour, 
                      'Minute' : rec['Date'].minute, 
                      'Second' :  rec['Date'].second,
                      'DayOfYear' : rec['Date'].dayofyear, 
                      'DayOfWeek' : rec['Date'].dayofweek, 
                      'WeekOfYear' :  rec['Date'].weekofyear,
                      'WeekOfYear' : rec['Date'].weekofyear, 
                      'Quarter' : rec['Date'].quarter,
                      'IsWeekend' : int(rec['Date'].dayofweek > 4), 
                      'IsMonthStart' : int(rec['Date'].is_month_start),
                      'IsMonthEnd' :  int(rec['Date'].is_month_end)
                     }), axis = 1)
        
        df = pd.concat([df, df1], axis=1)
        
        cloudHealthValues = {'FAIR' : 0, 'GOOD' : 1, 'CRITICAL' : 2}

        df.replace({'CloudHealthIndex': cloudHealthValues}, inplace=True)
        
        df = df[df.columns.drop(['Date'])]
        return df  #.as_matrix()
    
    def fit(self, df, y=None, **fit_params):
        
        return self;

# %%
preprocess = Preprocessor()
preprocess
# Out:
# Preprocessor()

# %%
X = preprocess.transform(sample_df)
y = sample_df.replace({'Label' : incidentTypesDict})['Label']

# %%
sample_df.replace({'Label' : incidentTypesDict})['Label'].head()
# Out:
# 0    6
# 1    6
# 2    3
# 3    2
# 4    5
# Name: Label, dtype: int64

# %%
sample_df['AvgBackgroundQ'].hist()

# %%
jsn1 = "[{'AvgBackgroundQ': 302, 'AvgThreadPoolSize': 7, 'AvgWorkflowQ': 32, 'CatalogSearchTime': 10, 'CloudHealthIndex': 'CRITICAL', 'Date': 1483228800000, 'IsProductReleased': 0, 'LogSizeVolumePercent': 0.087, 'NetworkConnectivitySNV-US1': 1, 'NodeId': 63, 'UiNodeThreadsCount': 403}]"
jsn1 = jsn1.replace("'", '"')

reqDf = pd.read_json(jsn1, orient='records')
ff= preprocess.transform(reqDf)
ff
# Out:
#    AvgBackgroundQ  AvgThreadPoolSize  AvgWorkflowQ  CatalogSearchTime  \
# 0             302                  7            32                 10
#
#    CloudHealthIndex  IsProductReleased  LogSizeVolumePercent  \
# 0                 2                  0                 0.087
#
#    NetworkConnectivitySNV-US1  UiNodeThreadsCount  Day     ...      Hour  \
# 0                           1                 403    1     ...         0
#
#    Minute  Second  DayOfYear  DayOfWeek  WeekOfYear  Quarter  IsWeekend  \
# 0       0       0          1          6          52        1          1
#
#    IsMonthStart  IsMonthEnd
# 0             1           0
#
# [1 rows x 22 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
import pickle
import dill as pickle

filename = 'model_v1.pk'

with open('models/'+filename, 'wb') as file:
    pickle.dump(knn, file)

# %%
y_train.head()
X_train.head()
# Out:
#       AvgBackgroundQ  AvgThreadPoolSize  AvgWorkflowQ  CatalogSearchTime  \
# 5085           116.0               10.0        -999.0                9.0
# 9032           187.0               10.0           8.0               16.0
# 4640           178.0                6.0          36.0                4.0
# 5357            47.0                9.0          26.0               17.0
# 1810           210.0                3.0           7.0               39.0
#
#       CloudHealthIndex  IsProductReleased  LogSizeVolumePercent  \
# 5085                 2                  1                 0.067
# 9032                 1                  1                 0.162
# 4640                 1                  0                 0.874
# 5357                 1                  0                 0.557
# 1810                 1                  1                 0.399
#
#       NetworkConnectivitySNV-US1  UiNodeThreadsCount  Day     ...      Hour  \
# 5085                           0               476.0   16     ...        22
# 9032                           1               281.0    8     ...         4
# 4640                           0               376.0    7     ...        16
# 5357                           0              -999.0   22     ...        14
# 1810                           1               308.0    7     ...        17
#
#       Minute  Second  DayOfYear  DayOfWeek  WeekOfYear  Quarter  IsWeekend  \
# 5085      30       0        106          6          15        2          1
# 9032       0       0        189          5          27        3          1
# 4640       0       0         97          4          14        2          0
# 5357      30       0        112          5          16        2          1
# 1810       0       0         38          1           6        1          0
#
#       IsMonthStart  IsMonthEnd
# 5085             0           0
# 9032             0           0
# 4640             0           0
# 5357             0           0
# 1810             0           0
#
# [5 rows x 22 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
knn.score(X_test, y_test)
# Out:
# 0.1276

# %%
knn.predict(ff)
# Out:
# array([0], dtype=int64)

# %%
sample_df.iloc[10:12] #.to_json(orient='records')
# Out:
#     AvgBackgroundQ  AvgWorkflowQ  AvgThreadPoolSize  NodeId  \
# 10             431            18                  1      61
# 11             219            36                  4      78
#
#     IsProductReleased  UiNodeThreadsCount  CatalogSearchTime  \
# 10                  1                 552                  9
# 11                  0                -341                 23
#
#     NetworkConnectivitySNV-US1  LogSizeVolumePercent              Label  \
# 10                           1                 0.716       NetworkIssue
# 11                           1                 0.185  DBConnectionIssue
#
#                   Date CloudHealthIndex
# 10 2017-01-01 05:00:00         CRITICAL
# 11 2017-01-01 05:30:00         CRITICAL
